# %% [markdown]
# <a href="https://colab.research.google.com/github/sap-28/Context-Aware-Misinformation-Detection/blob/src/Data%20preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EDA on Fake and Real News Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_fake = pd.read_csv("/content/drive/MyDrive/ML-Fake news detection/archive (5)/Fake.csv")
df_true = pd.read_csv("/content/drive/MyDrive/ML-Fake news detection/archive (5)/True.csv")
